# %% [markdown]
# This is a just a reference notebook showing what exists in different jsons of interest -- run through differing usages of get_names.py (changed the url to point to where I wanted to go)

# %%
# %%bash
#
# python get_names.py
# Out:
# {
#   "organizations": [
#     {
#       "url": "https://z3nplatformdevap.zendesk.com/api/v2/organizations/366775269013.json",
#       "id": 366775269013,
#       "name": "Platform Services AP",
#       "shared_tickets": false,
#       "shared_comments": false,
#       "external_id": null,
#       "created_at": "2019-05-30T09:18:36Z",
#       "updated_at": "2019-05-30T09:18:38Z",
#       "domain_names": [],
#       "details": null,
#       "notes": null,
#       "group_id": null,
#       "tags": [],
#       "organization_fields": {
#         "region": null
#       }
#     },
#     {
#       "url": "https://z3nplatformdevap.zendesk.com/api/v2/organizations/366790172254.json",
#       "id": 366790172254,
#       "name": "Test",
#       "shared_tickets": false,
#       "shared_comments": false,
#       "external_id": null,
#       "created_at": "2019-05-30T19:54:52Z",
#       "updated_at": "2019-05-30T19:54:52Z",
#       "domain_names": [
#         "acme@test.com"
#       ],
# ...

# %%
# %%bash
# python get_names.py
# Out:
# {
#   "users": [
#     {
#       "id": 380909561013,
#       "url": "https://z3nplatformdevap.zendesk.com/api/v2/users/380909561013.json",
#       "name": "Chris Meyers",
#       "email": "cmeyers+pfdap@zendesk.com",
#       "created_at": "2019-05-30T09:18:36Z",
#       "updated_at": "2019-06-01T11:49:24Z",
#       "time_zone": "Eastern Time (US & Canada)",
#       "iana_time_zone": "America/New_York",
#       "phone": null,
#       "shared_phone_number": null,
#       "photo": null,
#       "locale_id": 1,
#       "locale": "en-US",
#       "organization_id": 366775269013,
#       "role": "admin",
#       "verified": true,
#       "external_id": null,
#       "tags": [],
#       "alias": null,
#       "active": true,
#       "shared": false,
#       "shared_agent": false,
#       "last_login_at": "2019-06-01T11:49:24Z",
#       "two_factor_auth_enabled": null,
#       "signature": null,
#       "details": null,
#       "notes": null,
#       "role_type": null,
# ...

# %%
# %%bash
# python get_names.py
# Out:
# {
#   "tickets": [
#     {
#       "url": "https://z3nplatformdevap.zendesk.com/api/v2/tickets/1.json",
#       "id": 1,
#       "external_id": null,
#       "via": {
#         "channel": "sample_ticket",
#         "source": {
#           "from": {},
#           "to": {},
#           "rel": null
#         }
#       },
#       "created_at": "2019-05-30T09:18:36Z",
#       "updated_at": "2019-06-03T15:29:24Z",
#       "type": "incident",
#       "subject": "Sample ticket: Meet the ticket",
#       "raw_subject": "Sample ticket: Meet the ticket",
# ...

# %%
# %%bash
# python get_names.py
# Out:
# {
#   "ticket_fields": [
#     {
#       "url": "https://z3nplatformdevap.zendesk.com/api/v2/ticket_fields/360020147473.json",
#       "id": 360020147473,
#       "type": "subject",
#       "title": "Subject",
#       "raw_title": "Subject",
#       "description": "",
#       "raw_description": "",
#       "position": 1,
#       "active": true,
#       "required": false,
#       "collapsed_for_agents": false,
#       "regexp_for_validation": null,
#       "title_in_portal": "Subject",
#       "raw_title_in_portal": "Subject",
#       "visible_in_portal": true,
#       "editable_in_portal": true,
#       "required_in_portal": true,
#       "tag": null,
#       "created_at": "2019-05-30T09:18:36Z",
#       "updated_at": "2019-05-30T09:18:36Z",
#       "removable": false,
#       "agent_description": null
#     },
#     {
#       "url": "https://z3nplatformdevap.zendesk.com/api/v2/ticket_fields/360020147493.json",
#       "id": 360020147493,
#       "type": "description",
# ...

# %%
# %%bash
# python get_names.py
# Out:
# {
#   "user_fields": [
#     {
#       "url": "https://z3nplatformdevap.zendesk.com/api/v2/user_fields/360000718534.json",
#       "id": 360000718534,
#       "type": "text",
#       "key": "employee_id",
#       "title": "Employee ID",
#       "description": "",
#       "raw_title": "Employee ID",
#       "raw_description": "",
#       "position": 0,
#       "active": true,
#       "system": false,
#       "regexp_for_validation": null,
#       "created_at": "2019-05-30T10:11:46Z",
#       "updated_at": "2019-05-30T10:11:46Z"
#     },
#     {
#       "url": "https://z3nplatformdevap.zendesk.com/api/v2/user_fields/360000712413.json",
#       "id": 360000712413,
#       "type": "text",
#       "key": "promotion_code",
#       "title": "Promotion Code",
#       "description": "",
#       "raw_title": "Promotion Code",
#       "raw_description": "",
#       "position": 1,
#       "active": true,
#       "system": false,
#       "regexp_for_validation": null,
# ...

# %%
# %%bash
# python get_names.py
# Out:
# Python 3.7.3
